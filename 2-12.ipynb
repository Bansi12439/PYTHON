# %%
import os

# %%
os.getcwd()

# %%
os.chdir(r"C:\Users\LJENG\Desktop\B4")

# %%
os.getcwd()

# %%
os.mkdir("1.txt")

# %%
# %%writefile 2.txt
# hello

# %%
os.rmdir(r"C:\Users\LJENG\Desktop\B4\1.txt")

# %%
os.remove(r"C:\Users\LJENG\Desktop\B4\2.txt")

# %%
os.listdir(r"C:\\Users\\LJENG\\Desktop\\PYTHON_B4")

# %%
os.getcwd()

# %%
os.chdir(r"C:\Users\LJENG\Desktop\7")

# %%
os.getcwd()

# %%
os.mkdir("1")

# %%
os.mkdir("2")
os.mkdir("3")

# %%
os.chdir(r"C:\Users\LJENG\Desktop\7\1")

# %%
os.mkdir("11")

# %%
# %%writefile 2.txt
# hello

# %%
# %%writefile ae.py
a="hdsfj"
def demo(a):
    print(len(a))
    print(a[::-1])

# %%
import ae
ae.demo("sdgdfg")

# %%
import ae as p
p.demo("ghdf")

# %%
from ae import a
a

# %%
from ae import *
ae.demo("hgsh")

# %%
# %%writefile first_word.py
def ex(a):
    a.split()
    print(a[0])

# %%
import first_word
a=input("Enter string")
first_word.ex(a)
