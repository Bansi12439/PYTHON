# %%
f=open("1.txt","r")
x=f.read()
f.close()
print(x)
# Out:
# hello
# good morning

# %%
f=open("1.txt","r+")
f.write("BANSI")
f.read()
f.close()

# %%
f=open("2.txt","w+")
f.seek(0)
f.write("kkkk\n")
f.write("zzzz")
x=f.read()
f.close()
print(x)

# %%
f=open("3.txt","w+")
z=f.read()
d=open("4.txt","w")
d.write(z)
d.close()

# %%
f=open("new.txt","w+")
f.seek(0)
x=["abxghghg"]
f.writelines(x)

f=open("6.txt","r+")
z=f.read()
print(z)
x=z[::-1]
print(x)
f.close()

# %%
f=open("7.txt","w+")
f.write("xys\n eghd\n gdshgf\n vdfd\n agshfd\n ghfds")
f.seek(0)
z=f.read()
f.close()

f=open("8.txt","w+")
f.write("jyhj\n hgfh\n fhgfg\n gfasgf\n ghsdhg\n")
f.seek(0)
y=f.read()
f.close()

f=open("9.txt","w+")
f.write(z)
f.write(y)
f.close()

# %%
f=open("simple.txt","w+")
z=f.read()
f.seek(0)
f.close()


x=z.split(" ")
for i in x:
    k=x[0]+x[-1]
    m=k.upper()
print(m)
