# %%
print(===Trivago-style travel package calculator===)
n=int(input("enter number of travellers:"))
def destination(price):
    if  destination=goa:
        price=20000
    elif destination=kerala:
        price=22000
    elif destination=manali:
        price=18000
    elif destination=15000:
        price=15000
    else:
        print("none")
        
print("price of all destination",price)

def travelmode(price):
    if mode=flight:
        price=8000
    elif mode=train_AC:
        price=3000
    elif mode=train_NONAC:
        price=1500
    else:
        print("none")
        
print("the travel mode is",prices)

def hoteltype(price):
    if hotel=5star:
        price=5000
    elif hotel=3star:
        price=3000
    elif hotel=budget:
        price=1500
    else:
        print("none")
    
print("the hotel price is ",price)

def mealplan(price):
    if meal=fullmeals:
        price=4000
    elif meal=breakfastonly:
        price=2000
    else:
        print("no meal")
    
print("the hotel price is ",price)

def discount(total):
    if total>=50000:
        price=(50000*0.9)
    elif total>=40000:
        price=(40000*0.3)
    else:
        print("no discount")
print("with discount total is",total)

def GST(price):
    f_total=(total*0.18)
    print("the final total is",f_total)
    
def calculate_perperson_cost(total):
    total=base_price+travel_cost+hotel_cost+food_cost+sightseeing+seasonal_surcharge
print("total is",total)

destination=destination(price)
tavelmode=travelmode(price)
hoteltype=hoteltype(price)
mealplan=mealplan(price)

print("---full package details---")
print("destination is", destination)
print("trave mode is", tavelmode)
print("hoteltype is",hoteltype)
print("food plan is",mealplan)
