# %%
print("BANSI")

# %%
x="Happy New Year"
x[13]
x[0:13]
print(x[-1:-5:-3])
x[0:1000]
for i in x:
    print(i)
x[-1:-10:-4]
x[0:13:4]

# %%
a=input("Enter String : ")
n=len(a)
if n%2!=0:
    print(f"EVEN {a[0]+a[-1]}")
else:

# %%
a="Abc Abcdfe HIJKAD"
a.count("A",1,10)
a.split("A")
print("-".join(a))

# %%
a=input("enter string: ")
m=a.count("a")
print(m)
if m%2==0:
    ans=a.split("a")
    print(ans)
    
else:
    
    n=a.replace("a","@")
    s=n.lower()
    print(f"ANS: {n+s}")

# %%
a="Dhruv Dhoni"
m=a.find("r")
if m==-1:
    print("not found")
else:
    print(m)
# Out:
# 2

# %%
x="Avds Sghdg"
x.isalnum()
x.isdigit()
x.istitle()
# Out:
# True
