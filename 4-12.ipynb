# %%
a=10
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b3649862defd> in <module>
#       1 a=10
# ----> 2 print(x)
#
# NameError: name 'x' is not defined

# %%
l=[1,2,3]
l[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-8720c3f38de0> in <module>
#       1 l=[1,2,3]
# ----> 2 l[100]
#
# IndexError: list index out of range

# %%
if a>3
    print("js")
# Out:
#   File "<ipython-input-3-8fb09fe5f54a>", line 1
#     if a>3
#           ^
# SyntaxError: invalid syntax

# %%
a=10
b=0
print(a/b)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-6-d581e841244a> in <module>
#       1 a=10
#       2 b=0
# ----> 3 print(a/b)
#
# ZeroDivisionError: division by zero

# %%
a="hrloo"
b=int(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-36929c6c3fad> in <module>
#       1 a="hrloo"
# ----> 2 b=int(a)
#
# ValueError: invalid literal for int() with base 10: 'hrloo'

# %%
import os2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-dcc9586c002d> in <module>
# ----> 1 import os2
#
# ModuleNotFoundError: No module named 'os2'

# %%
l=[1,2,3]
l.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-75e5d8703574> in <module>
#       1 l=[1,2,3]
# ----> 2 l.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
a="hello"
b=10
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-9a155d812f67> in <module>
#       1 a="hello"
#       2 b=10
# ----> 3 print(a+b)
#
# TypeError: can only concatenate str (not "int") to str

# %%
try:
    a=10
    b=0
    print(a/b)
except:
    print("error")
finally:
    print("f")
# Out:
# error
# f

# %%
try:
    a=10
    b=0
    print(a/b)

except Exception as e:
    print(e)
except:
    print("b")
finally:
    print("f")
# Out:
# division by zero
# f

# %%
try:
    f=open("999.txt")
except:
    print("error")
else:
    x=f.write()
    print(x)
# Out:
# error

# %%
try:
    a=10
    b=0
    print(a/b)
except ZeroDivisionError:
    print("b")
# Out:
# b

# %%
class fun(Exception):
    pass
try:
    n=int(input("Enter mo no"))
    if n<10:
        raise fun("only 10 digit valid")
    else:
        print("success")
    
except fun as f:
    print(f)
# Out:
# Enter mo no9714634934
# success

# %%
import datetime
x=datetime.datetime.now()
print(x)
# Out:
# 2025-12-04 13:20:59.677502

# %%
import datetime
from datetime import date,time,datetime
y=int(input("enter year: "))
z=datetime(y,12,31,5,6,58)
x=datetime.now()
print(x)
# Out:
# enter year: 2025
# 2025-12-04 13:26:36.715128

# %%
z=date.today()
print(z)
# Out:
# 2025-12-04

# %%
y=datetime(2025,12,31,5,6,59)
print(y)
# Out:
# 2025-12-31 05:06:59
