# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3]
y=[7,8,9]
plt.plot(x,y)
plt.show()

# %%
import numpy as np
x=np.array([1,2,3])
y=np.array([5,6,7])
plt.xlabel("run")
plt.ylabel("match")
f={"family":"serif","color":"blue","size":30}
plt.title("graph",fontdict=f,loc="right")
plt.plot(x,y,marker="*",ms=20,mec="red",mfc="green",color="red",linewidth=5,linestyle="-.")
plt.show()

# %%
x=[1,2,3,4]
plt.plot(x)
plt.show()

# %%
p=["t1","t2","t3","t4"]
x=[20,25,12,31]
y=[12,3,8,23]
z=[21,32,12,14]
w=[5,10,45,36]
plt.subplot(2,2,1)
plt.plot(p,x)
#plt.show()
plt.subplot(2,2,2)
plt.plot(p,y)
#plt.show()
plt.subplot(2,2,3)
plt.plot(p,z)
# plt.show()
plt.subplot(2,2,4)
plt.plot(p,w)
plt.grid(color="red")
plt.savefig("SHOWING.png")
plt.show()

# %%
x=[1,2,3,4]
y=[10,20,30,40]
z=["red","green","blue","yellow"]
x1=[155,166,177,100]
plt.scatter(x,y,c=z,s=x1,alpha=0.5,marker="d")
plt.show()

# %%
x=[1,2,3,4]
y=[10,20,30,40]
# plt.bar(x,y,width=0.2)
plt.barh(x,y,height=0.1,color="yellow")
plt.show()

# %%
x=[10,20,50,40]
p=["t1","t2","t3","t4"]
e=[0,0,0.2,0]
plt.pie(x,autopct="%1.1f",labels=p,startangle=90,explode=e)
plt.legend(title="PIE")

plt.show()

# %%
x=["c","d","e","f",'a']
y=[4,5,6,1,4]
plt.subplot(5,2,1)
plt.pie(y,labels=x)
plt.subplot(5,2,4)
plt.plot(x,y)
plt.subplot(5,2,5)
plt.scatter(x,y)
plt.subplot(5,2,8)
plt.bar(x,y)
plt.subplot(5,2,9)
plt.barh(x,y)
plt.show()

# %%
x=[1,1,1,2,3,4,5,6]
y=[10,2,0,10,30,45,32,10]
plt.hist(x)
plt.show()
plt.fill_between(x,y)
plt.show()

# %%
import numpy as np

# %%
Scores=[[13,10,9,33],[63,46,90,42],[39,76,13,29],[82,9,29,78],[67,61,59,36]]
x=np.array(Scores)
print(x)
print()
match_5=[41,87,72,36,92]
y=np.array(match_5).reshape(5,1)
x1=np.concatenate((Scores,y),axis=1)
print(x1)
print()
b_6=[77,83,98,98,89]
b_7=[92,71,52,61,53]
x2=np.array(b_6).reshape(1,5)
x4=np.array(b_7).reshape(1,5)
x3=np.concatenate((x1,x2),axis=0)
print(x3)
print()
y=np.concatenate((x3,x4),axis=0)
print()
print(y)
c=np.sum(y,axis=1)
print("sum",c)
d=c.reshape(7,1)
e=np.concatenate((y,d),axis=1)
print(e)
# Out:
# [[13 10  9 33]
#  [63 46 90 42]
#  [39 76 13 29]
#  [82  9 29 78]
#  [67 61 59 36]]
#
# [[13 10  9 33 41]
#  [63 46 90 42 87]
#  [39 76 13 29 72]
#  [82  9 29 78 36]
#  [67 61 59 36 92]]
#
# [[13 10  9 33 41]
#  [63 46 90 42 87]
#  [39 76 13 29 72]
#  [82  9 29 78 36]
#  [67 61 59 36 92]
#  [77 83 98 98 89]]
#
#
# [[13 10  9 33 41]
#  [63 46 90 42 87]
#  [39 76 13 29 72]
#  [82  9 29 78 36]
#  [67 61 59 36 92]
#  [77 83 98 98 89]
#  [92 71 52 61 53]]
# sum [106 328 229 234 315 445 329]
# [[ 13  10   9  33  41 106]
#  [ 63  46  90  42  87 328]
#  [ 39  76  13  29  72 229]
#  [ 82   9  29  78  36 234]
#  [ 67  61  59  36  92 315]
#  [ 77  83  98  98  89 445]
#  [ 92  71  52  61  53 329]]

# %%
import matplotlib.pyplot as plt
Scores=[[13,10,9,33],[63,46,90,42],[39,76,13,29],[82,9,29,78],[67,61,59,36]]
x=np.array(Scores)
print(x)
print()
match_5=[41,87,72,36,92]
y=np.array(match_5).reshape(5,1)
x1=np.concatenate((Scores,y),axis=1)
print(x1)
print()
b_6=[77,83,98,98,89]
b_7=[92,71,52,61,53]
x2=np.array(b_6).reshape(1,5)
x4=np.array(b_7).reshape(1,5)
x3=np.concatenate((x1,x2),axis=0)
print(x3)
print()
y=np.concatenate((x3,x4),axis=0)
print()
print(y)
c1=np.max(y,axis=1)
print(c1)
plt.plot(c1)
plt.show()
c2=np.max(y,axis=0)
print(c2)
plt.barh(c2,width=10)
plt.show()
c3=c1/5
l=["t1","t2","t3","t5"]
print(c3)
plt.scatter()
plt.show()
# Out:
# [[13 10  9 33]
#  [63 46 90 42]
#  [39 76 13 29]
#  [82  9 29 78]
#  [67 61 59 36]]
#
# [[13 10  9 33 41]
#  [63 46 90 42 87]
#  [39 76 13 29 72]
#  [82  9 29 78 36]
#  [67 61 59 36 92]]
#
# [[13 10  9 33 41]
#  [63 46 90 42 87]
#  [39 76 13 29 72]
#  [82  9 29 78 36]
#  [67 61 59 36 92]
#  [77 83 98 98 89]]
#
#
# [[13 10  9 33 41]
#  [63 46 90 42 87]
#  [39 76 13 29 72]
#  [82  9 29 78 36]
#  [67 61 59 36 92]
#  [77 83 98 98 89]
#  [92 71 52 61 53]]
# [41 90 76 82 92 98 92]
# [92 83 98 98 92]
# [ 8.2 18.  15.2 16.4 18.4 19.6 18.4]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-f5a966c46131> in <module>
#      29 c3=c1/5
#      30 print(c3)
# ---> 31 plt.scatter(y,c3)
#      32 plt.show()
#
# ...
